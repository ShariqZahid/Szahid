# %% [markdown]
# <a href="https://colab.research.google.com/github/ShariqZahid/Szahid/blob/main/EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/ShariqZahid/Szahid.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Analyzing key factors responsible for app engagement and success is very crucial for the developers creating apps and listing them on Playstore.
#
# The Playstore apps has enormous potential to drive app-making businesses to success. Actionable insigths can be drawn for developers to work on and capture the Android market.
#
# Various insights like the type of app and category of app most popular among users can be drawn. Features in the app which is increasing user engagement. Also, the whitespaces and pain points that users are facing in those existing apps and ways to tackle those whitespaces in new apps can be extracted.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Key Factors Responsile for App Engagement and Success

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path ='/content/drive/MyDrive/EDA Project/'
ps_df = pd.read_csv(path+"Play Store Data.csv")
ur_df = pd.read_csv(path+"User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset first look
ps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# dataset first look
ur_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ps_df.shape
# Out:
# (10841, 13)

# %%
ur_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# Dataset Info
ur_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicates = ps_df[ps_df.duplicated()]
duplicates_count = len(duplicates)
duplicates_count
# Out:
# 483

# %%
non_duplicates_count = len(ps_df) - duplicates_count
non_duplicates_count
# Out:
# 10358

# %%
# Duplicates and Non-Duplicates visualization
plt.bar(['Non-duplicates', 'Duplicates'], [non_duplicates_count, duplicates_count])
plt.xlabel('Type of Row')
plt.ylabel('Number of Rows')
plt.title('Duplicate Rows in ps_df')
plt.show()

# %%
# Dataset Duplicate Value Count
dup_count = len(ur_df[ur_df.duplicated()])
dup_count
# Out:
# 33616

# %%
non_dup_count = len(ur_df) - dup_count
non_dup_count
# Out:
# 30679

# %%
# Duplicates and Non-Duplicates visualization
plt.bar(['Non-duplicates', 'Duplicates'], [non_dup_count, dup_count])
plt.xlabel('Type of Row')
plt.ylabel('Number of Rows')
plt.title('Duplicate Rows in ur_df')
plt.show()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ps_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
msno.bar(ps_df)
# Out:
# <Axes: >

# %%
# Missing Values/Null Values Count
ur_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
msno.bar(ur_df)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# There are two datasets and these given datasets belongs to the Play store, and we have to analyze key factors responsible for app engagement and success.
#
# The goal is to analyze the data and draw insights that is leading to the app being a hit or a failure that in turn could help the developers while creating and listing new apps on the Playstore.
#
# The Playstore dataset(ps_df) has 10841 Rows and 13 Columns. There are 1474 null values in Rating column, 1 null value each in Type and Content Rating column, 8 null values in current ver column and 3 null values in android ver column. Also, there are in total 483 duplicate values in the dataset.
#
# The User Review dataset(ur_df) has 64295 Rows and 5 Columns. There are 26868 null values in Translated_Review column and 26863 null values each in Sentiment, Sentiment_Polarity and Sentiment_Subjectivity Columns.
# Also, there are in total 33616 duplicate values in the dataset which is actually expected since the columns are mostly categorical in nature.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
ps_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Columns
ur_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
ps_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Dataset Describe
ur_df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# In Playsore dataset, variables are:-
# *   **App :** Name of the apps available in the dataset
# *   **Category :** Kind of App(Art and Design, Family etc)
# *   **Rating :** Ratings given by the user to the particular app(1 to 5)
# *   **Reviews :** Number of reviews of the users for the apps
# *   **Size :** Size of the app(in M)
# *    **Installs :** Number of times app installed
# *   **Type :** Type of app(Free/Paid)
# *   **Price :** Cost of the app(in $)
# *   **Content Rating :** Suitability of app according to age(Teen,Everyone,etc)
# *   **Genres :** More granular division of the kind of app
# *   **Last Updated :** Date of App last updated
# *   **Current Ver :** Current Version of the app
# *   **Android Ver :** Android version of the phone compatible with the app
#
# In User Review dataset, variables are:-
# *   **App :** Name of the apps available in the dataset
# *   **Translated_Review :** Review in another language translated to english
# *   **Sentiment :** Overall sentiment of the app user(Positive/Negative/Neutral)
# *   **Sentiment_Polarity :** Sentiment polarity refers to the degree of
# positivity or negativity of a review. It is often measured on a scale from -1 to +1, with -1 indicating very negative sentiment, +1 indicating very positive sentiment, and 0 indicating neutral sentiment.
# *   **Sentiment_Subjectivity :** Sentiment subjectivity refers to the degree to which a review is subjective or objective. It is often measured on a scale from 0 to 1, with 0 indicating a completely objective review and 1 indicating a completely subjective review.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Checking Unique Values for each variable.
for i in ps_df.columns.tolist():
  print("No. of unique values in ",i,"is",ps_df[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %%
# Checking Unique Values for each variable.
for i in ur_df.columns.tolist():
  print("No. of unique values in ",i,"is",ur_df[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
psdf=ps_df.drop_duplicates()

# %%
type(psdf)
# Out:
# pandas.core.frame.DataFrame

# %%
psdf.shape
# Out:
# (10358, 13)

# %%
# Grouped by 'App' in order to find out the counts of each app in the dataset.
# Ideally the occurence of each App in this dataset should be 1 but we can see that there are many apps occuring more than Once on this dataset.
psdf.groupby("App").size().reset_index(name='counts').sort_values(by = "counts", ascending=False)
# Out:
#                                                     App  counts
# 7302                                             ROBLOX       9
# 101                                         8 Ball Pool       7
# 1800                                     Bubble Shooter       6
# 9290                                    Zombie Catchers       6
# 5148                                         Helix Jump       6
# ...                                                 ...     ...
# 3280                         Dine In CT - Food Delivery       1
# 3281  Dino Defends king 3 – Dinosaur T rex Hunter Games       1
# 3282                                         Dino T-Rex       1
# 3283                           Dino War: Rise of Beasts       1
# 9659   🔥 Football Wallpapers 4K | Full HD Backgrounds 😍       1
#
# [9660 rows x 2 columns]

# %%
# showing 1 example - App Roblox occuring 9 times with almost all the parameters same.
# From our general understanding we know Roblox is a gaming app but due to some error it is shown in Family category also
# So, this is nothing but some human error during this dataset preparation.
psdf[psdf['App'] == 'ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1841   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1870   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2016   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2088   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2206   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 4527   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up
# 1701  2.347.225742  4.1 and up
# 1748  2.347.225742  4.1 and up
# 1841  2.347.225742  4.1 and up
# 1870  2.347.225742  4.1 and up
# 2016  2.347.225742  4.1 and up
# 2088  2.347.225742  4.1 and up
# 2206  2.347.225742  4.1 and up
# 4527  2.347.225742  4.1 and up

# %%
# Showing another example - App 8 Ball Pool occuring 7 times with all parameters same except Reviews which is fluctuating but negligibly.
psdf[psdf['App'] == '8 Ball Pool']
# Out:
#               App Category  Rating   Reviews Size      Installs  Type Price  \
# 1675  8 Ball Pool     GAME     4.5  14198297  52M  100,000,000+  Free     0
# 1703  8 Ball Pool     GAME     4.5  14198602  52M  100,000,000+  Free     0
# 1755  8 Ball Pool     GAME     4.5  14200344  52M  100,000,000+  Free     0
# 1844  8 Ball Pool     GAME     4.5  14200550  52M  100,000,000+  Free     0
# 1871  8 Ball Pool     GAME     4.5  14201891  52M  100,000,000+  Free     0
# 1970  8 Ball Pool     GAME     4.5  14201604  52M  100,000,000+  Free     0
# 3953  8 Ball Pool   SPORTS     4.5  14184910  52M  100,000,000+  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver   Android Ver
# 1675       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1703       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1755       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1844       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1871       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 1970       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 3953       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up

# %%
# Filtering single row on the basis of maximum reviews by applying Rank() function.
psdf["rank"] = psdf.groupby("App")["Reviews"].rank(method="dense", ascending=False)
psdf = psdf[psdf['rank'] == 1.0]
psdf.head()
# Out:
# <ipython-input-32-ce40eaff1fca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   psdf["rank"] = psdf.groupby("App")["Reviews"].rank(method="dense", ascending=False)
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# 5     167  5.6M      50,000+  Free     0       Everyone
#
#                     Genres     Last Updated         Current Ver   Android Ver  \
# 0             Art & Design  January 7, 2018               1.0.0  4.0.3 and up
# 2             Art & Design   August 1, 2018               1.2.4  4.0.3 and up
# 3             Art & Design     June 8, 2018  Varies with device    4.2 and up
# 4  Art & Design;Creativity    June 20, 2018                 1.1    4.4 and up
# 5             Art & Design   March 26, 2017                 1.0    2.3 and up
#
#    rank
# 0   1.0
# 2   1.0
# 3   1.0
# 4   1.0
# 5   1.0

# %%
# Outlier detected during dataset describe
psdf[psdf['Rating'] == 19.00]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  rank
# 10472       1.0.19  4.0 and up         NaN   1.0

# %%
# Deleted row containing rating as 19.0 because max value of rating is 5.0
psdf.drop([10472], axis = 0, inplace = True)

# %%
psdf[psdf['Rating'] == 19.00]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, rank]
# Index: []

# %%
# Checking unique values for 'Price' column
psdf['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$11.99', '$79.99', '$16.99', '$14.99', '$1.00',
#        '$29.99', '$12.99', '$2.49', '$24.99', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
# Removing '$' sign from the dataset(specifically from Price column)
psdf=psdf.replace('\$','',regex=True)

# %%
psdf['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '11.99', '79.99', '16.99', '14.99', '1.00', '29.99', '12.99',
#        '2.49', '24.99', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
# Checking unique values for 'Installs' column
psdf['Installs'].unique()
# Out:
# array(['10,000+', '5,000,000+', '50,000,000+', '100,000+', '50,000+',
#        '1,000,000+', '10,000,000+', '5,000+', '500,000+',
#        '1,000,000,000+', '100,000,000+', '1,000+', '500,000,000+', '50+',
#        '100+', '500+', '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# Converting Installs column from string to int
psdf['Installs'] = psdf['Installs'].str.replace('\+', '').str.replace(',', '').astype(int)
# Out:
# <ipython-input-40-d013af5130f4>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   psdf['Installs'] = psdf['Installs'].str.replace('\+', '').str.replace(',', '').astype(int)

# %%
psdf['Installs'].unique()
# Out:
# array([     10000,    5000000,   50000000,     100000,      50000,
#           1000000,   10000000,       5000,     500000, 1000000000,
#         100000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %%
# Creating a function which takes string as an argument and returns the original type
def convert_to_num(str):
  return eval(str)

# %%
# Converting Reviews column from string to int
psdf.loc[~psdf['Reviews'].isnull(), 'Reviews'] = psdf.loc[~psdf['Reviews'].isnull(), 'Reviews'].apply(convert_to_num)
# Out:
# <ipython-input-43-2a6b9b8feedc>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   psdf.loc[~psdf['Reviews'].isnull(), 'Reviews'] = psdf.loc[~psdf['Reviews'].isnull(), 'Reviews'].apply(convert_to_num)

# %%
psdf['Reviews'].unique()
# Out:
# array([   159,  87510, 215644, ...,    603,   1195, 398307])

# %%
# Converting Price column from String to Float
psdf.loc[~psdf['Price'].isnull(),'Price'] = psdf.loc[~psdf['Price'].isnull(), 'Price'].apply(convert_to_num)
# Out:
# <ipython-input-45-ea5b5f450b3d>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   psdf.loc[~psdf['Price'].isnull(),'Price'] = psdf.loc[~psdf['Price'].isnull(), 'Price'].apply(convert_to_num)

# %%
# Earlier only 'Rating' column was Float type
# Now, converted other columns like 'Reviews', 'Installs',  and 'Price' to Int and Float type since it is required for futher analysis
psdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9665 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9665 non-null   object
#  1   Category        9665 non-null   object
#  2   Rating          8202 non-null   float64
#  3   Reviews         9665 non-null   int64
#  4   Size            9665 non-null   object
#  5   Installs        9665 non-null   int64
#  6   Type            9664 non-null   object
#  7   Price           9665 non-null   float64
#  8   Content Rating  9665 non-null   object
#  9   Genres          9665 non-null   object
#  10  Last Updated    9665 non-null   object
#  11  Current Ver     9657 non-null   object
#  12  Android Ver     9663 non-null   object
#  13  rank            9665 non-null   float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
psdf.describe()
# Out:
#             Rating       Reviews      Installs        Price    rank
# count  8202.000000  9.665000e+03  9.665000e+03  9665.000000  9665.0
# mean      4.173226  2.165019e+05  7.779103e+06     1.099236     1.0
# std       0.536385  1.830833e+06  5.374346e+07    16.847012     0.0
# min       1.000000  0.000000e+00  0.000000e+00     0.000000     1.0
# 25%       4.000000  2.500000e+01  1.000000e+03     0.000000     1.0
# 50%       4.300000  9.690000e+02  1.000000e+05     0.000000     1.0
# 75%       4.500000  2.944500e+04  1.000000e+06     0.000000     1.0
# max       5.000000  7.815831e+07  1.000000e+09   400.000000     1.0

# %%
# Most Installed Categories
# Most popular category in terms of reviews
# Top app within the category popular among users in terms of reviews
# find top rated category
# find whether top rated category also has high no of reviews and higher no of installs
# check whether no. of installs is related to the type of app

# %%
# Top 10 most installed categories
psdf.groupby('Category').agg({'Installs':'mean'}).sort_values(by = 'Installs', ascending = False).reset_index().head(10)
# Out:
#              Category      Installs
# 0       COMMUNICATION  3.504215e+07
# 1       VIDEO_PLAYERS  2.397502e+07
# 2              SOCIAL  2.296179e+07
# 3         PHOTOGRAPHY  1.654501e+07
# 4        PRODUCTIVITY  1.548955e+07
# 5                GAME  1.419716e+07
# 6    TRAVEL_AND_LOCAL  1.321866e+07
# 7       ENTERTAINMENT  1.137540e+07
# 8               TOOLS  9.665587e+06
# 9  NEWS_AND_MAGAZINES  9.327629e+06

# %%
# Top Rated categories
psdf.groupby('Category').agg({'Rating':'mean'}).sort_values(by = 'Rating', ascending = False).reset_index().head(10)
# Out:
#               Category    Rating
# 0               EVENTS  4.435556
# 1       ART_AND_DESIGN  4.359322
# 2            EDUCATION  4.358879
# 3  BOOKS_AND_REFERENCE  4.344970
# 4      PERSONALIZATION  4.332215
# 5            PARENTING  4.300000
# 6               BEAUTY  4.278571
# 7               SOCIAL  4.247291
# 8                 GAME  4.243527
# 9              WEATHER  4.243056

# %%
# Top 10 categories popular among users in terms of reviews
most_popular = psdf.groupby("Category")['Reviews'].sum().reset_index().sort_values(by = "Reviews", ascending= False).head(10)
most_popular
# giving preference to more no of reviews than better ratings and taking these categories for future analysis
# go to charts for visualization
# Out:
#            Category    Reviews
# 14             GAME  588992954
# 6     COMMUNICATION  285824082
# 29            TOOLS  229565063
# 27           SOCIAL  227936355
# 11           FAMILY  193696025
# 24      PHOTOGRAPHY  105352365
# 31    VIDEO_PLAYERS   67644444
# 25     PRODUCTIVITY   55590856
# 23  PERSONALIZATION   53543117
# 26         SHOPPING   44622473

# %%
# Most popular app of a particular category among users in terms of reviews
psdf_sorted = psdf[['Category','App','Reviews']].sort_values(by = 'Reviews', ascending = False).drop_duplicates(subset=['Category']).head(10)
psdf_sorted
# go to charts for visualization
# Out:
#                 Category                                               App  \
# 2544              SOCIAL                                          Facebook
# 336        COMMUNICATION                                WhatsApp Messenger
# 1879                GAME                                    Clash of Clans
# 4005               TOOLS           Clean Master- Space Cleaner & Antivirus
# 3665       VIDEO_PLAYERS                                           YouTube
# 3739  NEWS_AND_MAGAZINES                                           Twitter
# 2884         PHOTOGRAPHY                                     Google Photos
# 2050              FAMILY          Minion Rush: Despicable Me Official Game
# 3223    TRAVEL_AND_LOCAL                         Maps - Navigate & Explore
# 4812     PERSONALIZATION  GO Launcher - 3D parallax Themes & HD Wallpapers
#
#        Reviews
# 2544  78158306
# 336   69119316
# 1879  44893888
# 4005  42916526
# 3665  25655305
# 3739  11667403
# 2884  10859051
# 2050  10216997
# 3223   9235373
# 4812   7464996

# %% [markdown]
# ### We can see that apps like Facebook, WhatsApp Messenger, Clash of Clans, Youtube, Twitter, etc are most popular in their respective categories.

# %%
#3 Top 5 apps with most reviews in GAME Category
game = psdf[psdf['Category']=='GAME'].sort_values(by='Reviews', ascending=False).head(5)
game
# Out:
#                    App Category  Rating   Reviews                Size  \
# 1879    Clash of Clans     GAME     4.6  44893888                 98M
# 1872    Subway Surfers     GAME     4.5  27725352                 76M
# 1878      Clash Royale     GAME     4.6  23136735                 97M
# 1869  Candy Crush Saga     GAME     4.4  22430188                 74M
# 1908    My Talking Tom     GAME     4.5  14892469  Varies with device
#
#         Installs  Type  Price Content Rating    Genres   Last Updated  \
# 1879   100000000  Free    0.0   Everyone 10+  Strategy  July 15, 2018
# 1872  1000000000  Free    0.0   Everyone 10+    Arcade  July 12, 2018
# 1878   100000000  Free    0.0   Everyone 10+  Strategy  June 27, 2018
# 1869   500000000  Free    0.0       Everyone    Casual   July 5, 2018
# 1908   500000000  Free    0.0       Everyone    Casual  July 19, 2018
#
#      Current Ver Android Ver  rank
# 1879   10.322.16  4.1 and up   1.0
# 1872      1.90.0  4.1 and up   1.0
# 1878       2.3.2  4.1 and up   1.0
# 1869   1.129.0.2  4.1 and up   1.0
# 1908   4.8.0.132  4.1 and up   1.0

# %%
game_b5 = game[['App','Genres','Reviews']]
game_b5
# Strategy games are most popular in terms of reviews
# Out:
#                    App    Genres   Reviews
# 1879    Clash of Clans  Strategy  44893888
# 1872    Subway Surfers    Arcade  27725352
# 1878      Clash Royale  Strategy  23136735
# 1869  Candy Crush Saga    Casual  22430188
# 1908    My Talking Tom    Casual  14892469

# %%
# Top 5 apps with most reviews in COMMUNICATION Category
comm = psdf[psdf['Category']=='COMMUNICATION'].sort_values(by='Reviews', ascending=False).head(5)
comm
# Out:
#                                               App       Category  Rating  \
# 336                            WhatsApp Messenger  COMMUNICATION     4.4
# 382      Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 420   UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 6449                  BBM - Free Calls & Messages  COMMUNICATION     4.3
# 4676                              Viber Messenger  COMMUNICATION     4.3
#
#        Reviews                Size    Installs  Type  Price Content Rating  \
# 336   69119316  Varies with device  1000000000  Free    0.0       Everyone
# 382   56646578  Varies with device  1000000000  Free    0.0       Everyone
# 420   17714850                 40M   500000000  Free    0.0           Teen
# 6449  12843436  Varies with device   100000000  Free    0.0       Everyone
# 4676  11335481  Varies with device   500000000  Free    0.0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver  \
# 336   Communication  August 3, 2018  Varies with device  Varies with device
# 382   Communication  August 1, 2018  Varies with device  Varies with device
# 420   Communication  August 2, 2018         12.8.5.1121          4.0 and up
# 6449  Communication  August 2, 2018  Varies with device        4.0.3 and up
# 4676  Communication   July 18, 2018  Varies with device  Varies with device
#
#       rank
# 336    1.0
# 382    1.0
# 420    1.0
# 6449   1.0
# 4676   1.0

# %%
comm_b5 = comm[['App','Genres','Reviews']]
comm_b5
# Out:
#                                               App         Genres   Reviews
# 336                            WhatsApp Messenger  Communication  69119316
# 382      Messenger – Text and Video Chat for Free  Communication  56646578
# 420   UC Browser - Fast Download Private & Secure  Communication  17714850
# 6449                  BBM - Free Calls & Messages  Communication  12843436
# 4676                              Viber Messenger  Communication  11335481

# %%
# Top 5 apps with most reviews in TOOLS Category
tool = psdf[psdf['Category']=='TOOLS'].sort_values(by='Reviews', ascending=False).head(5)
tool
# Out:
#                                                     App Category  Rating  \
# 4005            Clean Master- Space Cleaner & Antivirus    TOOLS     4.7
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...    TOOLS     4.7
# 4568    360 Security - Free Antivirus, Booster, Cleaner    TOOLS     4.6
# 8896  DU Battery Saver - Battery Charger & Battery Life    TOOLS     4.5
# 8894  Cache Cleaner-DU Speed Booster (booster & clea...    TOOLS     4.5
#
#        Reviews                Size   Installs  Type  Price Content Rating  \
# 4005  42916526  Varies with device  500000000  Free    0.0       Everyone
# 7536  24900999  Varies with device  500000000  Free    0.0       Everyone
# 4568  16771865  Varies with device  100000000  Free    0.0       Everyone
# 8896  13479633                 14M  100000000  Free    0.0       Everyone
# 8894  12759815                 15M  100000000  Free    0.0       Everyone
#
#      Genres    Last Updated         Current Ver         Android Ver  rank
# 4005  Tools  August 3, 2018  Varies with device  Varies with device   1.0
# 7536  Tools  August 4, 2018               4.6.6  Varies with device   1.0
# 4568  Tools  August 4, 2018  Varies with device  Varies with device   1.0
# 8896  Tools    June 5, 2018             4.8.7.8          4.0 and up   1.0
# 8894  Tools   July 25, 2018               3.1.2          4.0 and up   1.0

# %%
tool_b5 = tool[['App','Genres','Reviews']]
tool_b5
# Out:
#                                                     App Genres   Reviews
# 4005            Clean Master- Space Cleaner & Antivirus  Tools  42916526
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...  Tools  24900999
# 4568    360 Security - Free Antivirus, Booster, Cleaner  Tools  16771865
# 8896  DU Battery Saver - Battery Charger & Battery Life  Tools  13479633
# 8894  Cache Cleaner-DU Speed Booster (booster & clea...  Tools  12759815

# %%
# Top 5 apps with most reviews in SOCIAL Category
social = psdf[psdf['Category']=='SOCIAL'].sort_values(by='Reviews', ascending=False).head(5)
social
# Out:
#                 App Category  Rating   Reviews                Size  \
# 2544       Facebook   SOCIAL     4.1  78158306  Varies with device
# 2604      Instagram   SOCIAL     4.5  66577446  Varies with device
# 2610       Snapchat   SOCIAL     4.0  17015352  Varies with device
# 2546  Facebook Lite   SOCIAL     4.3   8606259  Varies with device
# 6373             VK   SOCIAL     3.8   5793284  Varies with device
#
#         Installs  Type  Price Content Rating  Genres    Last Updated  \
# 2544  1000000000  Free    0.0           Teen  Social  August 3, 2018
# 2604  1000000000  Free    0.0           Teen  Social   July 31, 2018
# 2610   500000000  Free    0.0           Teen  Social   July 30, 2018
# 2546   500000000  Free    0.0           Teen  Social  August 1, 2018
# 6373   100000000  Free    0.0     Mature 17+  Social  August 3, 2018
#
#              Current Ver         Android Ver  rank
# 2544  Varies with device  Varies with device   1.0
# 2604  Varies with device  Varies with device   1.0
# 2610  Varies with device  Varies with device   1.0
# 2546  Varies with device  Varies with device   1.0
# 6373  Varies with device  Varies with device   1.0

# %%
social_b5 = social[['App','Genres','Reviews']]
social_b5
# Out:
#                 App  Genres   Reviews
# 2544       Facebook  Social  78158306
# 2604      Instagram  Social  66577446
# 2610       Snapchat  Social  17015352
# 2546  Facebook Lite  Social   8606259
# 6373             VK  Social   5793284

# %%
# Top 5 apps with most reviews in FAMILY Category
family = psdf[psdf['Category']=='FAMILY'].sort_values(by='Reviews', ascending=False).head(5)
family
# Out:
#                                             App Category  Rating   Reviews  \
# 2050   Minion Rush: Despicable Me Official Game   FAMILY     4.5  10216997
# 3975                                    Hay Day   FAMILY     4.5  10053186
# 10186                          Farm Heroes Saga   FAMILY     4.4   7615646
# 5856                          Google Play Games   FAMILY     4.3   7168735
# 8439             Duolingo: Learn Languages Free   FAMILY     4.7   6297590
#
#                      Size    Installs  Type  Price Content Rating  \
# 2050   Varies with device   100000000  Free    0.0   Everyone 10+
# 3975                  94M   100000000  Free    0.0       Everyone
# 10186                 71M   100000000  Free    0.0       Everyone
# 5856   Varies with device  1000000000  Free    0.0           Teen
# 8439   Varies with device   100000000  Free    0.0       Everyone
#
#                           Genres    Last Updated         Current Ver  \
# 2050   Casual;Action & Adventure   July 12, 2018  Varies with device
# 3975                      Casual   June 28, 2018             1_39_93
# 10186                     Casual  August 7, 2018               5.2.6
# 5856               Entertainment   July 16, 2018  Varies with device
# 8439         Education;Education  August 6, 2018  Varies with device
#
#               Android Ver  rank
# 2050   Varies with device   1.0
# 3975         4.0.3 and up   1.0
# 10186          2.3 and up   1.0
# 5856   Varies with device   1.0
# 8439   Varies with device   1.0

# %%
family_b5 = family[['App','Genres','Reviews']]
family_b5
# Casual;Action & Adventure	is the most popular genre in FAMILY Category basically casual is doing good in this category
# Out:
#                                             App                     Genres  \
# 2050   Minion Rush: Despicable Me Official Game  Casual;Action & Adventure
# 3975                                    Hay Day                     Casual
# 10186                          Farm Heroes Saga                     Casual
# 5856                          Google Play Games              Entertainment
# 8439             Duolingo: Learn Languages Free        Education;Education
#
#         Reviews
# 2050   10216997
# 3975   10053186
# 10186   7615646
# 5856    7168735
# 8439    6297590

# %%
#5 Free apps are more installed
selected_categories = ['GAME','COMMUNICATION','TOOLS','SOCIAL','FAMILY','PHOTOGRAPHY','VIDEO_PLAYERS','PRODUCTIVITY', 'PERSONALIZATION', 'SHOPPING']
filtered_psdf = psdf[psdf['Category'].isin(selected_categories)]
free_vs_paid= filtered_psdf.groupby(['Category','Type']).Installs.sum().reset_index()
free_vs_paid
# We can see huge difference in number of installs between Free and Paid apps of same category.
# It is actually expected because people usually install and use Free apps mostly.
# see chart in visualization section
# Out:
#            Category  Type     Installs
# 0     COMMUNICATION  Free  11036916201
# 1     COMMUNICATION  Paid      1360050
# 2            FAMILY  Free   6221491691
# 3            FAMILY  Paid     21150814
# 4              GAME  Free  13366924450
# 5              GAME  Paid     20999965
# 6   PERSONALIZATION  Free   1529235988
# 7   PERSONALIZATION  Paid      3258794
# 8       PHOTOGRAPHY  Free   4647268915
# 9       PHOTOGRAPHY  Paid      1878740
# 10     PRODUCTIVITY  Free   5791679314
# 11     PRODUCTIVITY  Paid      1412055
# 12         SHOPPING  Free   1410338685
# 13         SHOPPING  Paid        10100
# 14           SOCIAL  Free   5487861902
# 15           SOCIAL  Paid         6000
# 16            TOOLS  Free   8011044474
# 17            TOOLS  Paid      1727441
# 18    VIDEO_PLAYERS  Free   3931831720
# 19    VIDEO_PLAYERS  Paid        71000

# %%
# ~ 42% of the records have null values in ur_df
#df1.shape
ur_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
ur_df.shape
# Out:
# (64295, 5)

# %%
ur_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Dropping rows containing null values because mostly categorical columns are present in this dataset.
urdf = ur_df.dropna()
urdf
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# 64222  Most ads older many agents ..not much owner po...  Positive
# 64223  If photos posted portal load, fit purpose. I'm...  Positive
# 64226  Dumb app, I wanted post property rent give opt...  Negative
# 64227  I property business got link SMS happy perform...  Positive
# 64230  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# ...                   ...                     ...
# 64222            0.173333                0.486667
# 64223            0.225000                0.447222
# 64226           -0.287500                0.250000
# 64227            0.800000                1.000000
# 64230           -0.316667                0.400000
#
# [37427 rows x 5 columns]

# %%
urdf.shape
# Out:
# (37427, 5)

# %%
urdf.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
urdf1 = urdf.copy()

# %%
urdf1=urdf.groupby(['App']).agg({'Sentiment_Polarity':'mean','Sentiment_Subjectivity':'mean'}).reset_index()
urdf1
# Out:
#                                                    App  Sentiment_Polarity  \
# 0                                10 Best Foods for You            0.470733
# 1                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室            0.392405
# 2                                                 11st            0.185943
# 3                           1800 Contacts - Lens Store            0.318145
# 4                      1LINE – One Line with One Touch            0.196290
# ..                                                 ...                 ...
# 860  Hotels.com: Book Hotel Rooms & Find Vacation D...            0.101622
# 861     Hotspot Shield Free VPN Proxy & Wi-Fi Security            0.251765
# 862                                            Hotstar            0.038178
# 863                     Hotwire Hotel & Car Rental App            0.187029
# 864                     Housing-Real Estate & Property           -0.021427
#
#      Sentiment_Subjectivity
# 0                  0.495455
# 1                  0.545516
# 2                  0.455340
# 3                  0.591098
# 4                  0.557315
# ..                      ...
# 860                0.545444
# 861                0.393284
# 862                0.493964
# 863                0.459717
# 864                0.378532
#
# [865 rows x 3 columns]

# %%
#Sentiment count for apps sorted by highest positive sentiments
urdf2 = urdf.groupby('App')['Sentiment'].value_counts().unstack().fillna(0).sort_values(by = 'Positive', ascending = False)
urdf2
# go to charts section for visualization
# Out:
# Sentiment                       Negative  Neutral  Positive
# App
# Helix Jump                          58.0      6.0     209.0
# Duolingo: Learn Languages Free      34.0      6.0     200.0
# Calorie Counter - Macros            20.0      6.0     174.0
# Bowmasters                         119.0     24.0     169.0
# Calorie Counter - MyFitnessPal      52.0     33.0     169.0
# ...                                  ...      ...       ...
# Free Live Talk-Video Call            1.0      0.0       0.0
# DEER HUNTER 2018                     3.0      0.0       0.0
# Google Street View                   3.0      1.0       0.0
# HD Camera                            0.0      1.0       0.0
# Draw Your Game                       2.0      0.0       0.0
#
# [865 rows x 3 columns]

# %%
# Adding a column named 'Total'
urdf2['Total'] = urdf2['Positive']+urdf2['Neutral']+urdf2['Negative']

# %%
# Adding a column named 'Positive_Percentage'
urdf2['Positive_Percentage'] = round((urdf2['Positive']/(urdf2['Positive']+urdf2['Neutral']+urdf2['Negative']))*100,1)

# %%
# Sorting with Total and Positive Percentage
urdf2.sort_values(by = ['Total','Positive_Percentage'], ascending = False).head(10)
# Out:
# Sentiment                       Negative  Neutral  Positive  Total  \
# App
# Bowmasters                         119.0     24.0     169.0  312.0
# Helix Jump                          58.0      6.0     209.0  273.0
# Angry Birds Classic                147.0      2.0     124.0  273.0
# Calorie Counter - MyFitnessPal      52.0     33.0     169.0  254.0
# Duolingo: Learn Languages Free      34.0      6.0     200.0  240.0
# Candy Crush Saga                   126.0     12.0     102.0  240.0
# Garena Free Fire                    81.0      5.0     136.0  222.0
# 8 Ball Pool                        106.0      9.0     104.0  219.0
# Calorie Counter - Macros            20.0      6.0     174.0  200.0
# 10 Best Foods for You               10.0     22.0     162.0  194.0
#
# Sentiment                       Positive_Percentage
# App
# Bowmasters                                     54.2
# Helix Jump                                     76.6
# Angry Birds Classic                            45.4
# Calorie Counter - MyFitnessPal                 66.5
# Duolingo: Learn Languages Free                 83.3
# Candy Crush Saga                               42.5
# Garena Free Fire                               61.3
# 8 Ball Pool                                    47.5
# Calorie Counter - Macros                       87.0
# 10 Best Foods for You                          83.5

# %%
urdf_new = pd.merge(urdf1, urdf2, on='App')
urdf_new
# Out:
#                                                    App  Sentiment_Polarity  \
# 0                                10 Best Foods for You            0.470733
# 1                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室            0.392405
# 2                                                 11st            0.185943
# 3                           1800 Contacts - Lens Store            0.318145
# 4                      1LINE – One Line with One Touch            0.196290
# ..                                                 ...                 ...
# 860  Hotels.com: Book Hotel Rooms & Find Vacation D...            0.101622
# 861     Hotspot Shield Free VPN Proxy & Wi-Fi Security            0.251765
# 862                                            Hotstar            0.038178
# 863                     Hotwire Hotel & Car Rental App            0.187029
# 864                     Housing-Real Estate & Property           -0.021427
#
#      Sentiment_Subjectivity  Negative  Neutral  Positive  Total  \
# 0                  0.495455      10.0     22.0     162.0  194.0
# 1                  0.545516       1.0      8.0      31.0   40.0
# 2                  0.455340       7.0      9.0      23.0   39.0
# 3                  0.591098       6.0     10.0      64.0   80.0
# 4                  0.557315       8.0      3.0      27.0   38.0
# ..                      ...       ...      ...       ...    ...
# 860                0.545444      21.0      8.0      39.0   68.0
# 861                0.393284       3.0     14.0      17.0   34.0
# 862                0.493964      14.0      4.0      14.0   32.0
# 863                0.459717       6.0     11.0      16.0   33.0
# 864                0.378532      10.0      3.0       8.0   21.0
#
#      Positive_Percentage
# 0                   83.5
# 1                   77.5
# 2                   59.0
# 3                   80.0
# 4                   71.1
# ..                   ...
# 860                 57.4
# 861                 50.0
# 862                 43.8
# 863                 48.5
# 864                 38.1
#
# [865 rows x 8 columns]

# %%
urdf_new.sort_values(by = ['Total','Positive_Percentage'], ascending = False).head(10)
# Out:
#                                 App  Sentiment_Polarity  \
# 256                      Bowmasters            0.061415
# 817                      Helix Jump            0.099665
# 114             Angry Birds Classic           -0.007537
# 328  Calorie Counter - MyFitnessPal            0.216523
# 510  Duolingo: Learn Languages Free            0.200408
# 334                Candy Crush Saga            0.031068
# 718                Garena Free Fire            0.071158
# 22                      8 Ball Pool            0.001252
# 327        Calorie Counter - Macros            0.247519
# 0             10 Best Foods for You            0.470733
#
#      Sentiment_Subjectivity  Negative  Neutral  Positive  Total  \
# 256                0.500548     119.0     24.0     169.0  312.0
# 817                0.487221      58.0      6.0     209.0  273.0
# 114                0.534886     147.0      2.0     124.0  273.0
# 328                0.474814      52.0     33.0     169.0  254.0
# 510                0.470215      34.0      6.0     200.0  240.0
# 334                0.456293     126.0     12.0     102.0  240.0
# 718                0.494133      81.0      5.0     136.0  222.0
# 22                 0.491352     106.0      9.0     104.0  219.0
# 327                0.512675      20.0      6.0     174.0  200.0
# 0                  0.495455      10.0     22.0     162.0  194.0
#
#      Positive_Percentage
# 256                 54.2
# 817                 76.6
# 114                 45.4
# 328                 66.5
# 510                 83.3
# 334                 42.5
# 718                 61.3
# 22                  47.5
# 327                 87.0
# 0                   83.5

# %%
# Inner Join
df1 = pd.merge(psdf, urdf_new, on = 'App')
df1.head()
# Out:
#                                          App        Category  Rating  Reviews  \
# 0                       Garden Coloring Book  ART_AND_DESIGN     4.4    13791
# 1              FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3   194216
# 2  Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1      654
# 3              Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260
# 4                      Animated Photo Editor  ART_AND_DESIGN     4.1      203
#
#    Size  Installs  Type  Price Content Rating                   Genres  ...  \
# 0   33M   1000000  Free    0.0       Everyone             Art & Design  ...
# 1   39M   5000000  Free    0.0       Everyone             Art & Design  ...
# 2   12M    100000  Free    0.0       Everyone             Art & Design  ...
# 3   25M    500000  Free    0.0       Everyone  Art & Design;Creativity  ...
# 4  6.1M    100000  Free    0.0       Everyone             Art & Design  ...
#
#   Current Ver   Android Ver rank  Sentiment_Polarity  Sentiment_Subjectivity  \
# 0       2.9.2    3.0 and up  1.0            0.268483                0.523447
# 1       2.2.5  4.0.3 and up  1.0            0.412649                0.679226
# 2         1.1  4.0.3 and up  1.0            0.283509                0.479298
# 3       1.0.8  4.0.3 and up  1.0            0.171836                0.572762
# 4        1.03  4.0.3 and up  1.0            0.291857                0.546365
#
#    Negative  Neutral  Positive  Total  Positive_Percentage
# 0      10.0     16.0      64.0   90.0                 71.1
# 1       0.0      0.0       4.0    4.0                100.0
# 2       5.0     10.0      23.0   38.0                 60.5
# 3       8.0      1.0      29.0   38.0                 76.3
# 4       4.0     10.0      21.0   35.0                 60.0
#
# [5 rows x 21 columns]

# %%
df1 = df1.drop(['Last Updated', 'Current Ver', 'Android Ver', 'Price', 'rank'], axis = 1)
df1.head()
# Out:
#                                          App        Category  Rating  Reviews  \
# 0                       Garden Coloring Book  ART_AND_DESIGN     4.4    13791
# 1              FlipaClip - Cartoon animation  ART_AND_DESIGN     4.3   194216
# 2  Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1      654
# 3              Colorfit - Drawing & Coloring  ART_AND_DESIGN     4.7    20260
# 4                      Animated Photo Editor  ART_AND_DESIGN     4.1      203
#
#    Size  Installs  Type Content Rating                   Genres  \
# 0   33M   1000000  Free       Everyone             Art & Design
# 1   39M   5000000  Free       Everyone             Art & Design
# 2   12M    100000  Free       Everyone             Art & Design
# 3   25M    500000  Free       Everyone  Art & Design;Creativity
# 4  6.1M    100000  Free       Everyone             Art & Design
#
#    Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 0            0.268483                0.523447      10.0     16.0      64.0
# 1            0.412649                0.679226       0.0      0.0       4.0
# 2            0.283509                0.479298       5.0     10.0      23.0
# 3            0.171836                0.572762       8.0      1.0      29.0
# 4            0.291857                0.546365       4.0     10.0      21.0
#
#    Total  Positive_Percentage
# 0   90.0                 71.1
# 1    4.0                100.0
# 2   38.0                 60.5
# 3   38.0                 76.3
# 4   35.0                 60.0

# %%
df1.sort_values(by = ['Total','Positive_Percentage'], ascending = False).head(10)
# Out:
#                                 App            Category  Rating   Reviews  \
# 359                      Bowmasters                GAME     4.7   1536349
# 329                      Helix Jump                GAME     4.2   1500999
# 354             Angry Birds Classic                GAME     4.4   5566908
# 227  Calorie Counter - MyFitnessPal  HEALTH_AND_FITNESS     4.6   1873523
# 784  Duolingo: Learn Languages Free              FAMILY     4.7   6297590
# 313                Candy Crush Saga                GAME     4.4  22430188
# 814                Garena Free Fire                GAME     4.5   5534114
# 314                     8 Ball Pool                GAME     4.5  14201891
# 232        Calorie Counter - Macros  HEALTH_AND_FITNESS     4.0      3061
# 231           10 Best Foods for You  HEALTH_AND_FITNESS     4.0      2490
#
#                    Size   Installs  Type Content Rating               Genres  \
# 359  Varies with device   50000000  Free           Teen               Action
# 329                 33M  100000000  Free       Everyone               Action
# 354                 97M  100000000  Free       Everyone               Arcade
# 227  Varies with device   50000000  Free       Everyone     Health & Fitness
# 784  Varies with device  100000000  Free       Everyone  Education;Education
# 313                 74M  500000000  Free       Everyone               Casual
# 814                 53M  100000000  Free           Teen               Action
# 314                 52M  100000000  Free       Everyone               Sports
# 232                5.5M     100000  Free       Everyone     Health & Fitness
# 231                3.8M     500000  Free   Everyone 10+     Health & Fitness
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 359            0.061415                0.500548     119.0     24.0     169.0
# 329            0.099665                0.487221      58.0      6.0     209.0
# 354           -0.007537                0.534886     147.0      2.0     124.0
# 227            0.216523                0.474814      52.0     33.0     169.0
# 784            0.200408                0.470215      34.0      6.0     200.0
# 313            0.031068                0.456293     126.0     12.0     102.0
# 814            0.071158                0.494133      81.0      5.0     136.0
# 314            0.001252                0.491352     106.0      9.0     104.0
# 232            0.247519                0.512675      20.0      6.0     174.0
# 231            0.470733                0.495455      10.0     22.0     162.0
#
#      Total  Positive_Percentage
# 359  312.0                 54.2
# 329  273.0                 76.6
# 354  273.0                 45.4
# 227  254.0                 66.5
# 784  240.0                 83.3
# 313  240.0                 42.5
# 814  222.0                 61.3
# 314  219.0                 47.5
# 232  200.0                 87.0
# 231  194.0                 83.5

# %%
#1 Top 10 categories popular among users in terms of reviews
top_category = psdf.groupby("Category")['Reviews'].sum().reset_index().sort_values(by = "Reviews", ascending= False).head(10)
top_category
# giving preference to more no of reviews than better ratings and taking these categories for future analysis
# Out:
#            Category    Reviews
# 14             GAME  588992954
# 6     COMMUNICATION  285824082
# 29            TOOLS  229565063
# 27           SOCIAL  227936355
# 11           FAMILY  193696025
# 24      PHOTOGRAPHY  105352365
# 31    VIDEO_PLAYERS   67644444
# 25     PRODUCTIVITY   55590856
# 23  PERSONALIZATION   53543117
# 26         SHOPPING   44622473

# %%
# Top 5 apps with most reviews in GAME Category
g = df1[df1['Category']=='GAME'].sort_values(by='Reviews', ascending=False).head(5)
g
# Out:
#                           App Category  Rating   Reviews Size   Installs  \
# 317            Clash of Clans     GAME     4.6  44893888  98M  100000000
# 316              Clash Royale     GAME     4.6  23136735  97M  100000000
# 313          Candy Crush Saga     GAME     4.4  22430188  74M  500000000
# 314               8 Ball Pool     GAME     4.5  14201891  52M  100000000
# 326  Dream League Soccer 2018     GAME     4.6   9883806  74M  100000000
#
#      Type Content Rating    Genres  Sentiment_Polarity  \
# 317  Free   Everyone 10+  Strategy            0.036756
# 316  Free   Everyone 10+  Strategy            0.069157
# 313  Free       Everyone    Casual            0.031068
# 314  Free       Everyone    Sports            0.001252
# 326  Free       Everyone    Sports           -0.000518
#
#      Sentiment_Subjectivity  Negative  Neutral  Positive  Total  \
# 317                0.533956      10.0      0.0      23.0   33.0
# 316                0.489236      58.0      0.0     107.0  165.0
# 313                0.456293     126.0     12.0     102.0  240.0
# 314                0.491352     106.0      9.0     104.0  219.0
# 326                0.483124       1.0      0.0       2.0    3.0
#
#      Positive_Percentage
# 317                 69.7
# 316                 64.8
# 313                 42.5
# 314                 47.5
# 326                 66.7

# %%
# Top 5 apps in GAME Category sorted by Total no of Sentiments and Positive_Percentage of sentiments
g5 = df1[df1['Category']=='GAME'].sort_values(by=['Total','Positive_Percentage'], ascending=False).head(5)
g5
# Out:
#                      App Category  Rating   Reviews                Size  \
# 359           Bowmasters     GAME     4.7   1536349  Varies with device
# 329           Helix Jump     GAME     4.2   1500999                 33M
# 354  Angry Birds Classic     GAME     4.4   5566908                 97M
# 313     Candy Crush Saga     GAME     4.4  22430188                 74M
# 814     Garena Free Fire     GAME     4.5   5534114                 53M
#
#       Installs  Type Content Rating  Genres  Sentiment_Polarity  \
# 359   50000000  Free           Teen  Action            0.061415
# 329  100000000  Free       Everyone  Action            0.099665
# 354  100000000  Free       Everyone  Arcade           -0.007537
# 313  500000000  Free       Everyone  Casual            0.031068
# 814  100000000  Free           Teen  Action            0.071158
#
#      Sentiment_Subjectivity  Negative  Neutral  Positive  Total  \
# 359                0.500548     119.0     24.0     169.0  312.0
# 329                0.487221      58.0      6.0     209.0  273.0
# 354                0.534886     147.0      2.0     124.0  273.0
# 313                0.456293     126.0     12.0     102.0  240.0
# 814                0.494133      81.0      5.0     136.0  222.0
#
#      Positive_Percentage
# 359                 54.2
# 329                 76.6
# 354                 45.4
# 313                 42.5
# 814                 61.3

# %%
# Top 5 apps with most reviews in COMM Category
c = df1[df1['Category']=='COMMUNICATION'].sort_values(by='Reviews', ascending=False).head(5)
c
# Out:
#                                             App       Category  Rating  \
# 765                 BBM - Free Calls & Messages  COMMUNICATION     4.3
# 73                                        Gmail  COMMUNICATION     4.3
# 76                                     Hangouts  COMMUNICATION     4.0
# 64               Firefox Browser fast & private  COMMUNICATION     4.4
# 61   GO SMS Pro - Messenger, Free Themes, Emoji  COMMUNICATION     4.4
#
#       Reviews                Size    Installs  Type Content Rating  \
# 765  12843436  Varies with device   100000000  Free       Everyone
# 73    4604483  Varies with device  1000000000  Free       Everyone
# 76    3419513  Varies with device  1000000000  Free       Everyone
# 64    3075118  Varies with device   100000000  Free       Everyone
# 61    2876500                 24M   100000000  Free       Everyone
#
#             Genres  Sentiment_Polarity  Sentiment_Subjectivity  Negative  \
# 765  Communication            0.154423                0.461890       8.0
# 73   Communication            0.071383                0.465920      22.0
# 76   Communication            0.251503                0.531249      12.0
# 64   Communication            0.110142                0.518786      17.0
# 61   Communication            0.202488                0.439832       4.0
#
#      Neutral  Positive  Total  Positive_Percentage
# 765      9.0      18.0   35.0                 51.4
# 73       9.0      33.0   64.0                 51.6
# 76      16.0      86.0  114.0                 75.4
# 64       0.0      45.0   62.0                 72.6
# 61       9.0      13.0   26.0                 50.0

# %%
# Top 5 apps in COMMUNICATION Category sorted by Total no of Sentiments and Positive_Percentage of sentiments
c5 = df1[df1['Category']=='COMMUNICATION'].sort_values(by=['Total','Positive_Percentage'], ascending=False).head(5)
c5
# Out:
#                                     App       Category  Rating  Reviews  \
# 76                             Hangouts  COMMUNICATION     4.0  3419513
# 737                                Azar  COMMUNICATION     4.2  1092337
# 816  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 73                                Gmail  COMMUNICATION     4.3  4604483
# 64       Firefox Browser fast & private  COMMUNICATION     4.4  3075118
#
#                    Size    Installs  Type Content Rating         Genres  \
# 76   Varies with device  1000000000  Free       Everyone  Communication
# 737  Varies with device    50000000  Free     Mature 17+  Communication
# 816                4.0M     1000000  Free       Everyone  Communication
# 73   Varies with device  1000000000  Free       Everyone  Communication
# 64   Varies with device   100000000  Free       Everyone  Communication
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 76             0.251503                0.531249      12.0     16.0      86.0
# 737            0.068404                0.481706      25.0     29.0      38.0
# 816            0.209249                0.553828       4.0      6.0      54.0
# 73             0.071383                0.465920      22.0      9.0      33.0
# 64             0.110142                0.518786      17.0      0.0      45.0
#
#      Total  Positive_Percentage
# 76   114.0                 75.4
# 737   92.0                 41.3
# 816   64.0                 84.4
# 73    64.0                 51.6
# 64    62.0                 72.6

# %%
# Top 5 apps with most reviews in TOOLS Category
t = df1[df1['Category']=='TOOLS'].sort_values(by='Reviews', ascending=False).head(5)
t
# Out:
#                                                    App Category  Rating  \
# 791  Cache Cleaner-DU Speed Booster (booster & clea...    TOOLS     4.5
# 564                                             Google    TOOLS     4.4
# 565                                   Google Translate    TOOLS     4.4
# 760                                            AppLock    TOOLS     4.4
# 604         GO Keyboard - Cute Emojis, Themes and GIFs    TOOLS     4.5
#
#       Reviews                Size    Installs  Type Content Rating Genres  \
# 791  12759815                 15M   100000000  Free       Everyone  Tools
# 564   8033493  Varies with device  1000000000  Free       Everyone  Tools
# 565   5745093  Varies with device   500000000  Free       Everyone  Tools
# 760   4931562  Varies with device   100000000  Free       Everyone  Tools
# 604   4594198  Varies with device   100000000  Free       Everyone  Tools
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 791            0.278521                0.457077       2.0      8.0      16.0
# 564            0.260359                0.492744       3.0      7.0      28.0
# 565            0.214167                0.490000       0.0      0.0       2.0
# 760            0.016233                0.499941       7.0      0.0       6.0
# 604            0.223901                0.310613       1.0     13.0      15.0
#
#      Total  Positive_Percentage
# 791   26.0                 61.5
# 564   38.0                 73.7
# 565    2.0                100.0
# 760   13.0                 46.2
# 604   29.0                 51.7

# %%
# Top 5 apps in TOOLS Category sorted by Total no of Sentiments and Positive_Percentage of sentiments
t5 = df1[df1['Category']=='TOOLS'].sort_values(by=['Total','Positive_Percentage'], ascending=False).head(5)
t5
# Out:
#                                  App Category  Rating  Reviews  \
# 606  CM Locker - Security Lockscreen    TOOLS     4.6  3090727
# 595              Graphing Calculator    TOOLS     3.9    12388
# 574     Gboard - the Google Keyboard    TOOLS     4.2  1859115
# 580              Digital Alarm Clock    TOOLS     4.2   118439
# 600                  Fast Secure VPN    TOOLS     4.3    56848
#
#                    Size   Installs  Type Content Rating Genres  \
# 606  Varies with device  100000000  Free       Everyone  Tools
# 595                5.3M    1000000  Free       Everyone  Tools
# 574  Varies with device  500000000  Free       Everyone  Tools
# 580                 16M   10000000  Free       Everyone  Tools
# 600                9.6M    1000000  Free       Everyone  Tools
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 606            0.240055                0.480304      15.0     15.0      56.0
# 595            0.245830                0.464479      13.0     14.0      52.0
# 574            0.064587                0.517172      34.0      2.0      40.0
# 580            0.341073                0.480795       5.0      7.0      59.0
# 600            0.179100                0.418541      11.0     23.0      37.0
#
#      Total  Positive_Percentage
# 606   86.0                 65.1
# 595   79.0                 65.8
# 574   76.0                 52.6
# 580   71.0                 83.1
# 600   71.0                 52.1

# %%
# Top 5 apps with most reviews in SOCIAL Category
s = df1[df1['Category']=='SOCIAL'].sort_values(by='Reviews', ascending=False).head(5)
s
# Out:
#                                 App Category  Rating   Reviews  \
# 434                        Facebook   SOCIAL     4.1  78158306
# 435                   Facebook Lite   SOCIAL     4.3   8606259
# 436                         Google+   SOCIAL     4.2   4831125
# 441  Badoo - Free Chat & Dating App   SOCIAL     4.3   3781770
# 803    Amino: Communities and Chats   SOCIAL     4.8   1264084
#
#                    Size    Installs  Type Content Rating  Genres  \
# 434  Varies with device  1000000000  Free           Teen  Social
# 435  Varies with device   500000000  Free           Teen  Social
# 436  Varies with device  1000000000  Free           Teen  Social
# 441  Varies with device   100000000  Free     Mature 17+  Social
# 803                 62M    10000000  Free           Teen  Social
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 434           -0.007003                0.460207      60.0     19.0      53.0
# 435           -0.000991                0.456127      14.0      3.0      12.0
# 436            0.368056                0.469444       0.0      0.0       2.0
# 441            0.128489                0.416103      27.0     35.0      58.0
# 803            0.047590                0.537536      12.0      0.0      23.0
#
#      Total  Positive_Percentage
# 434  132.0                 40.2
# 435   29.0                 41.4
# 436    2.0                100.0
# 441  120.0                 48.3
# 803   35.0                 65.7

# %%
# Top 5 apps in SOCIAL Category sorted by Total no of Sentiments and Positive_Percentage of sentiments
s5 = df1[df1['Category']=='SOCIAL'].sort_values(by=['Total','Positive_Percentage'], ascending=False).head(5)
s5
# Out:
#                                 App Category  Rating   Reviews  \
# 434                        Facebook   SOCIAL     4.1  78158306
# 441  Badoo - Free Chat & Dating App   SOCIAL     4.3   3781770
# 445                           Banjo   SOCIAL     4.2     58341
# 443                      Bloglovin'   SOCIAL     3.9      8936
# 439    HTC Social Plugin - Facebook   SOCIAL     3.6     13223
#
#                    Size    Installs  Type Content Rating  Genres  \
# 434  Varies with device  1000000000  Free           Teen  Social
# 441  Varies with device   100000000  Free     Mature 17+  Social
# 445                9.3M     1000000  Free       Everyone  Social
# 443  Varies with device      500000  Free       Everyone  Social
# 439                2.8M    10000000  Free     Mature 17+  Social
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 434           -0.007003                0.460207      60.0     19.0      53.0
# 441            0.128489                0.416103      27.0     35.0      58.0
# 445            0.230850                0.464122       6.0      6.0      27.0
# 443            0.133953                0.469378       7.0     13.0      19.0
# 439           -0.051705                0.494052      20.0      5.0      14.0
#
#      Total  Positive_Percentage
# 434  132.0                 40.2
# 441  120.0                 48.3
# 445   39.0                 69.2
# 443   39.0                 48.7
# 439   39.0                 35.9

# %%
# Top 5 apps with most reviews in FAMILY Category
f = df1[df1['Category']=='FAMILY'].sort_values(by='Reviews', ascending=False).head(5)
f
# Out:
#                                 App Category  Rating   Reviews  \
# 750                         Hay Day   FAMILY     4.5  10053186
# 810                Farm Heroes Saga   FAMILY     4.4   7615646
# 784  Duolingo: Learn Languages Free   FAMILY     4.7   6297590
# 811                 Fallout Shelter   FAMILY     4.6   2721923
# 798     Episode - Choose Your Story   FAMILY     4.3   1842381
#
#                    Size   Installs  Type Content Rating               Genres  \
# 750                 94M  100000000  Free       Everyone               Casual
# 810                 71M  100000000  Free       Everyone               Casual
# 784  Varies with device  100000000  Free       Everyone  Education;Education
# 811                 25M   10000000  Free           Teen           Simulation
# 798  Varies with device   50000000  Free           Teen           Simulation
#
#      Sentiment_Polarity  Sentiment_Subjectivity  Negative  Neutral  Positive  \
# 750            0.019572                0.503682      24.0      3.0      34.0
# 810           -0.011811                0.444434      43.0     21.0      46.0
# 784            0.200408                0.470215      34.0      6.0     200.0
# 811            0.170232                0.513606       4.0      1.0      27.0
# 798            0.080274                0.481147      48.0     18.0      94.0
#
#      Total  Positive_Percentage
# 750   61.0                 55.7
# 810  110.0                 41.8
# 784  240.0                 83.3
# 811   32.0                 84.4
# 798  160.0                 58.8

# %%
# Top 5 apps in FAMILY Category sorted by Total no of Sentiments and Positive_Percentage of sentiments
f5 = df1[df1['Category']=='FAMILY'].sort_values(by=['Total','Positive_Percentage'], ascending=False).head(5)
f5
# Out:
#                                 App Category  Rating  Reviews  \
# 784  Duolingo: Learn Languages Free   FAMILY     4.7  6297590
# 798     Episode - Choose Your Story   FAMILY     4.3  1842381
# 370                  Bubble Shooter   FAMILY     4.4    59843
# 810                Farm Heroes Saga   FAMILY     4.4  7615646
# 780            DC Super Hero Girls™   FAMILY     4.3    43090
#
#                    Size   Installs  Type Content Rating  \
# 784  Varies with device  100000000  Free       Everyone
# 798  Varies with device   50000000  Free           Teen
# 370                 20M    5000000  Free       Everyone
# 810                 71M  100000000  Free       Everyone
# 780                 95M    5000000  Free       Everyone
#
#                         Genres  Sentiment_Polarity  Sentiment_Subjectivity  \
# 784        Education;Education            0.200408                0.470215
# 798                 Simulation            0.080274                0.481147
# 370         Puzzle;Brain Games            0.253676                0.515660
# 810                     Casual           -0.011811                0.444434
# 780  Action;Action & Adventure            0.334009                0.573327
#
#      Negative  Neutral  Positive  Total  Positive_Percentage
# 784      34.0      6.0     200.0  240.0                 83.3
# 798      48.0     18.0      94.0  160.0                 58.8
# 370      40.0      5.0     100.0  145.0                 69.0
# 810      43.0     21.0      46.0  110.0                 41.8
# 780       9.0      3.0      90.0  102.0                 88.2

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
hm = sns.heatmap(psdf[['Rating', 'Installs', 'Reviews', 'Price']].corr(), annot=True)
# we can see that the corelation between Rating and Installs is minutely related. So, we can say Rating of an app is Independent of Installs

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is a graphical tool that displays the correlation between multiple variables as a color-coded matrix. In a correlation heatmap, each variable is represented by a row and a column, and the cells show the correlation between them. The color of each cell represents the strength and direction of the correlation, with darker colors indicating stronger correlations.
#
# Thus, reason for using correlation heatmap is to find the correlation between the variables in my playstore dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the heatmap, we can see that only Installs is correlated to Reviews which is actually expected as apps with higher installs have more number of reviews.
#
# Apart from above, all other variables are mostly independent of each other or showing minute correlation.
# It is unexpected that Rating-Installs and Rating-Reviews are minutely related as from general understanding, More number of Installs should also translate to higher rating which is not exactly the case here.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Top 10 categories popular among users in terms of reviews
most_popular = psdf.groupby("Category")['Reviews'].sum().reset_index().sort_values(by = "Reviews", ascending= False).head(10)

# plotting the top 10 categories
plt.figure(figsize=(20,7))
sns.barplot(x = 'Category',
            y = 'Reviews',
            data = most_popular)
# Out:
# <Axes: xlabel='Category', ylabel='Reviews'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### A bar graph can be defined as a graphical representation of data, quantities, or numbers using bars or strips. They are used to compare and contrast different types of data, frequencies, or other measures of distinct categories of data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We got to know the top 10 categories popular among users in terms of Reviews.
#
# Also, one interesting thing to note from the above graph is that Game Category(which is the most reviewed category) has nearly 50% more reciews than the 2nd best Category- Communication.
# So, the Gap in popularity between top 2 categories is very huge.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights are very useful as it shows top 10 popular categories in terms of number of reviews.
# It gives clear idea that the chances of app being a hit is more if it belongs to above categories as they are widely accepted.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Most popular app of a particular category among users in terms of reviews
psdf_sorted = psdf[['Category','App','Reviews']].sort_values(by = 'Reviews', ascending = False).drop_duplicates(subset=['Category']).head(10)

fig, ax = plt.subplots(figsize = (11,8))

# Iterate through unique categories and plot them
for category, group in psdf_sorted.groupby('Category'):
    ax.scatter(group['App'], group['Reviews'], label=category)

# Customize the plot
ax.set_xlabel('Apps')
ax.set_ylabel('Number of Reviews')
ax.set_title('Apps with Highest number of Reviews for Top 10 Categories ')
ax.legend(loc = 'upper right')

# Rotate the x-axis labels for better readability if needed
plt.xticks(rotation = 60, ha = 'right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is a type of data visualization that shows the relationship between different variables. This data is shown by placing various data points between an x- and y-axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above chart shows the Apps with highest number of reviews in their respective categories.
#
# Facebook from Social Category, Whatsapp from Communication category and Clash of Clans from Game category are the top 3 apps most popular among users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely, the above insights are very useful as it shows Apps within the categories that are popular and succesfull among users.
#
# So, developers looking to develop new apps can consider the top 10 categories and if needed can dive deep into apps level to see what is trending and more acceptable to users. And, can develop new apps accordingly.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
selected_categories = ['GAME','COMMUNICATION','TOOLS','SOCIAL','FAMILY','PHOTOGRAPHY','VIDEO_PLAYERS','PRODUCTIVITY', 'PERSONALIZATION', 'SHOPPING']
filtered_psdf = psdf[psdf['Category'].isin(selected_categories)]
free_vs_paid= filtered_psdf.groupby(['Category','Type']).Installs.sum().reset_index()

# Pivoting the rows to columns for 'Type' column
free_vs_paid_pivot = free_vs_paid.pivot(index = 'Category', columns = 'Type', values = 'Installs')

# Calculating bar width and index
num_categories = 10
bar_width = 0.35
index = np.arange(num_categories)
categories = free_vs_paid['Category'].unique()

fig1, ax1 = plt.subplots(figsize=(15, 10))

free_bars = ax1.bar(index, free_vs_paid_pivot['Free'], bar_width, label='Free')
paid_bars = ax1.bar(index + bar_width, free_vs_paid_pivot['Paid'], bar_width, label='Paid')

ax1.set_xlabel('Category')
ax1.set_ylabel('Number of Installs')
ax1.set_title('Number of Installs by Category and Type')
ax1.set_xticks(index + bar_width / 2)
ax1.set_xticklabels(categories)
ax1.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### A bar graph can be defined as a graphical representation of data, quantities, or numbers using bars or strips. They are used to compare and contrast different types of data, frequencies, or other measures of distinct categories of data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# On drawing comparison between the Free and Paid apps of our top 10 categories, it is absolutely clear from the graph that Free apps are much more accepted and installed among people than the Paid apps.
#
# Paid apps are almost negligble. Only, Family and Game category have few apps which are accepted among people.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact as it clearly depicts that for App to be a success, it has to be 'Free'. People tend to install and try apps which are free. And if they like the app, then they may make some in app purchases.
#
# But, Paid apps usually cater to very small and niche segment of people and hence the chances of getting such app being a hit is very miniscule.

# %% [markdown]
# #### Chart - 5

# %%
#Sentiment count for apps sorted by highest positive sentiments
urdf2 = urdf.groupby('App')['Sentiment'].value_counts().unstack().fillna(0).sort_values(by = 'Positive', ascending = False)

# Chart - 5 visualization code
urdf2.head(10).plot(kind='bar', stacked=False)
plt.xlabel('App')
plt.ylabel('Sentiment Count')
plt.title('Sentiment Count for Apps')
plt.legend(title='Sentiment')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Bar graphs are particularly useful for comparing data across different categories or groups. Each bar represents a category, and the height or length of the bar corresponds to the value or frequency of the data in that category. This makes it easy to visually compare the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# On plotting the Sentiment count for apps, 6 out of the top 10 apps in terms of highest number of positive sentiment belongs to the top 10 categories.
#
# Game Category is coincidentally the most popular category and 4 out of 10 Apps belongs to this category which shows that user sentiment is highely positive towards this category.
#
# Also, one category i.e. 'Health and Fitness' which was not in our list of top 10 catgories also has high positive sentiments as 4 out of top 10 apps belong to this category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely, the gained insights are very useful and help create positive business impact as we discovered that there is One specific Category - 'Health and Fitness' which is although not vey popular and not much downloaded is garnering positive sentiments among users.
#
# It shows that this category can be one such niche where it is targeted to small user base but the acceptance level among users are very high.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# So, in order to achieve the Business Objective, the following points should be kept in mind:
#
#
#  * The apps should belong to top 10 categories like 'Game', 'Communication', 'Tools', 'Social', etc.
#  * Strategy based games are more popular as 2 out of top 5 games belong to Genre-Strategy.
#  * Casual apps in Family category is more preferred as 3 out of top5 apps belong to 'Casual' Genre.
#
#  * The apps should cater to a large segment of population.
#
#  * Apps must be introduced as 'Free' and later in app purchases can be used to drive revenue through the apps.
#
#  * The User sentiment is positive towards the top 10 categories.
#
#  * One Niche category - 'Health and Fitness' although not belonging to the list of top 10 categories is able to harness positive user sentiments.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In order to increase the chances of app to be successfull, it should belong
# to the Top 10 categories which include Game,Communication, Tools, Social, Family, etc.
#
# *    Also, when we dig deeper into our top 10 categories to find out which all apps are most popular, we found apps like 'Whatsapp', 'Facebook', 'Clash of Clans', 'Twitter' etc. which we clearly know that how popular and widely accepted these apps are. So, the developers looking to create app in Game category now knows that Strategy based games are more played and hence has clear understanding of what to create.
#
#
# *   Also, for apps to become successfull, it has to be introduced as Free instead of charging a Fee. Because, people tend to download and use Free apps much more. Instead, in app purchases can be better approach to drive the income through those apps.
#
# *   Also, one very important thing to note is that, 'Health and Fitness' is a category which although could not come to our list of top 10 categories is able to harness positive sentiment among users.
# This clearly indicates that people in this niche category are happy with the existing apps and introducing new app in this category can be difficult but rewarding.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
